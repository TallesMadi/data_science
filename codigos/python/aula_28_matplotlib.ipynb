# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 2, 4, 8, 16, 32]
y = [1, 3, 6, 12, 24, 28]

# %%
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico')
plt.plot(x, y)
plt.show()

# %%
a = [1, 2, 3, 4, 5]
b = [0.5, 0.75, 1, 15, 10, 7, 21, 16]

fig = plt.figure(figsize=(10, 10))

sub1 = plt.subplot(2, 2, 1)
sub1.set_title('Gráfico 1')
sub2 = plt.subplot(2, 2, 2)
sub2.set_title('Gráfico 2')
# tamanho 2, 2 e posição de 1 a 4
sub1.plot(a, 'sb') # colors = linha, sb, or, Dm para mais tipos
sub2.plot(b, 'or')
plt.draw()

# %%
import pandas as pd
data = pd.read_csv(r'C:\data_science\desafios\deafio_pratico_3\desafio_pratico_3.csv')
data
# Out:
#     ID_Produto    Categoria  Preco_R$  Quantidade_Vendida  Data_Venda
# 0          101  Eletrônicos      2500                   5  2024-01-05
# 1          102  Eletrônicos      2200                   8  2024-01-07
# 2          103         Moda       150                  25  2024-02-01
# 3          104         Moda       200                  18  2024-02-15
# 4          105       Beleza        90                  32  2024-03-10
# 5          106       Beleza       120                  28  2024-03-22
# 6          107     Esportes       300                  15  2024-04-05
# 7          108     Esportes       280                  20  2024-04-12
# 8          109  Eletrônicos      2100                  10  2024-05-05
# 9          110         Casa       450                  12  2024-05-18
# 10         111  Eletrônicos      1800                   7  2024-06-01
# 11         112  Eletrônicos      2600                   3  2024-06-10
# ...

# %%
data = data.drop('ID_Produto', axis=1)

# %%
data
# Out:
#       Categoria  Preco_R$  Quantidade_Vendida  Data_Venda
# 0   Eletrônicos      2500                   5  2024-01-05
# 1   Eletrônicos      2200                   8  2024-01-07
# 2          Moda       150                  25  2024-02-01
# 3          Moda       200                  18  2024-02-15
# 4        Beleza        90                  32  2024-03-10
# 5        Beleza       120                  28  2024-03-22
# 6      Esportes       300                  15  2024-04-05
# 7      Esportes       280                  20  2024-04-12
# 8   Eletrônicos      2100                  10  2024-05-05
# 9          Casa       450                  12  2024-05-18
# 10  Eletrônicos      1800                   7  2024-06-01
# 11  Eletrônicos      2600                   3  2024-06-10
# 12       Beleza       110                  25  2024-07-02
# 13     Esportes       320                  22  2024-07-15
# 14         Moda       170                  30  2024-08-08
# ...

# %%
data['Categoria'] = data['Categoria'].astype('category')
data['Data_Venda'] = data['Data_Venda'].astype('str')
data['Preco_R$'] = data['Preco_R$'].astype('float')
data['Quantidade_Vendida'] = data['Quantidade_Vendida'].astype('int')

data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# color: define a cor da linha.
#
# linewidth: define a espessura da linha.
#
# linestyle: define o estilo da linha.
#
# marker: define o tipo de marcador usado para cada ponto.
#
# markersize: define o tamanho dos marcadores.
#
# xlabel e ylabel: definem os rótulos dos eixos x e y, respectivamente.
#
# title: define o título do gráfico.
#
# grid: ativa a grade de fundo.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, color='red', linewidth=2, linestyle='dashed', marker='o', markersize=8)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Linha')
plt.grid(True)
plt.show()
