# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\data_science\dataset\atlas2010.csv', delimiter=',')

# %%
df.head()
# Out:
#     ano        uf      mun               nome_mun         nome_micro  \
# 0  2010  Rondonia  1100015  alta floresta d'oeste             cacoal
# 1  2010  Rondonia  1100023              ariquemes          ariquemes
# 2  2010  Rondonia  1100031                 cabixi  colorado do oeste
# 3  2010  Rondonia  1100049                 cacoal             cacoal
# 4  2010  Rondonia  1100056             cerejeiras  colorado do oeste
#
#            nome_meso  espvida  fectot  mort1  mort5  ...  pia18m    pop  \
# 0  leste rondoniense    70.75    2.24   23.8  25.49  ...   16431  24097
# 1  leste rondoniense    73.36    1.91   19.2  20.53  ...   60213  89766
# 2  leste rondoniense    70.39    2.15   24.8  26.58  ...    4306   6303
# 3  leste rondoniense    74.27    1.90   14.3  15.38  ...   54356  78141
# 4  leste rondoniense    72.94    2.12   18.1  19.42  ...   11786  16942
#
#     popt  i_escolaridade  i_freq_prop  idhm  idhm_e  idhm_l  idhm_r  falsa
# ...

# %%
df = df.set_index('mun')
df
# Out:
#           ano                uf               nome_mun           nome_micro  \
# mun
# 1100015  2010          Rondonia  alta floresta d'oeste               cacoal
# 1100023  2010          Rondonia              ariquemes            ariquemes
# 1100031  2010          Rondonia                 cabixi    colorado do oeste
# 1100049  2010          Rondonia                 cacoal               cacoal
# 1100056  2010          Rondonia             cerejeiras    colorado do oeste
# ...       ...               ...                    ...                  ...
# 5222005  2010             Goias             vianópolis         pires do rio
# 5222054  2010             Goias         vicentinópolis           meia ponte
# 5222203  2010             Goias               vila boa  entorno de brasília
# 5222302  2010             Goias          vila propício  entorno de brasília
# 5300108  2010  Distrito Federal               brasília             brasília
#
# ...

# %%
df.loc[1100049]
# Out:
# ano                        2010
# uf                     Rondonia
# nome_mun                 cacoal
# nome_micro               cacoal
# nome_meso     leste rondoniense
#                     ...
# idhm                        1.0
# idhm_e                     0.62
# idhm_l                      1.0
# idhm_r                      1.0
# falsa                       4,1
# Name: 1100049, Length: 238, dtype: object

# %%
df = df.reset_index()
df
# Out:
#           mun   ano                uf               nome_mun  \
# 0     1100015  2010          Rondonia  alta floresta d'oeste
# 1     1100023  2010          Rondonia              ariquemes
# 2     1100031  2010          Rondonia                 cabixi
# 3     1100049  2010          Rondonia                 cacoal
# 4     1100056  2010          Rondonia             cerejeiras
# ...       ...   ...               ...                    ...
# 5560  5222005  2010             Goias             vianópolis
# 5561  5222054  2010             Goias         vicentinópolis
# 5562  5222203  2010             Goias               vila boa
# 5563  5222302  2010             Goias          vila propício
# 5564  5300108  2010  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# 1               ariquemes  leste rondoniense    73.36    1.91  19.20  20.53
# ...

# %%
df.loc[df['espvida'] > 78.5, ['espvida', 'nome_mun', 'nome_meso']]
# Out:
#       espvida            nome_mun             nome_meso
# 4336    78.62  balneário camboriú        vale do itajaí
# 4346    78.64            blumenau        vale do itajaí
# 4357    78.64             brusque        vale do itajaí
# 4521    78.59     rancho queimado  grande florianópolis
# 4524    78.52        rio do oeste        vale do itajaí
# 4526    78.61          rio do sul        vale do itajaí

# %%
df.iloc[0:4, 0:3]
# Out:
#        mun   ano        uf
# 0  1100015  2010  Rondonia
# 1  1100023  2010  Rondonia
# 2  1100031  2010  Rondonia
# 3  1100049  2010  Rondonia

# %%
df['classificacao_fectot'] = df['fectot'].apply(lambda x: 'maior' if x >= 2 else 'menor')
df
# Out:
#           mun   ano                uf               nome_mun  \
# 0     1100015  2010          Rondonia  alta floresta d'oeste
# 1     1100023  2010          Rondonia              ariquemes
# 2     1100031  2010          Rondonia                 cabixi
# 3     1100049  2010          Rondonia                 cacoal
# 4     1100056  2010          Rondonia             cerejeiras
# ...       ...   ...               ...                    ...
# 5560  5222005  2010             Goias             vianópolis
# 5561  5222054  2010             Goias         vicentinópolis
# 5562  5222203  2010             Goias               vila boa
# 5563  5222302  2010             Goias          vila propício
# 5564  5300108  2010  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# 1               ariquemes  leste rondoniense    73.36    1.91  19.20  20.53
# ...

# %%
mapeamento = {'maior': 1, 'menor': 0}

# %%
df['mapeado'] = df['classificacao_fectot'].map(mapeamento)
df
# Out:
#           mun   ano                uf               nome_mun  \
# 0     1100015  2010          Rondonia  alta floresta d'oeste
# 1     1100023  2010          Rondonia              ariquemes
# 2     1100031  2010          Rondonia                 cabixi
# 3     1100049  2010          Rondonia                 cacoal
# 4     1100056  2010          Rondonia             cerejeiras
# ...       ...   ...               ...                    ...
# 5560  5222005  2010             Goias             vianópolis
# 5561  5222054  2010             Goias         vicentinópolis
# 5562  5222203  2010             Goias               vila boa
# 5563  5222302  2010             Goias          vila propício
# 5564  5300108  2010  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# 1               ariquemes  leste rondoniense    73.36    1.91  19.20  20.53
# ...

# %%
df['diferenca'] = 2025 - df['ano']
df
# Out:
#           mun   ano                uf               nome_mun  \
# 0     1100015  2010          Rondonia  alta floresta d'oeste
# 1     1100023  2010          Rondonia              ariquemes
# 2     1100031  2010          Rondonia                 cabixi
# 3     1100049  2010          Rondonia                 cacoal
# 4     1100056  2010          Rondonia             cerejeiras
# ...       ...   ...               ...                    ...
# 5560  5222005  2010             Goias             vianópolis
# 5561  5222054  2010             Goias         vicentinópolis
# 5562  5222203  2010             Goias               vila boa
# 5563  5222302  2010             Goias          vila propício
# 5564  5300108  2010  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# 1               ariquemes  leste rondoniense    73.36    1.91  19.20  20.53
# ...

# %%
df['diferenca'] = df['diferenca'].astype(int)

# %%
df['ano'] = pd.to_datetime(df['ano'], format='%Y')

# %%
df['ano']
# Out:
# 0      2010-01-01
# 1      2010-01-01
# 2      2010-01-01
# 3      2010-01-01
# 4      2010-01-01
#           ...
# 5560   2010-01-01
# 5561   2010-01-01
# 5562   2010-01-01
# 5563   2010-01-01
# 5564   2010-01-01
# Name: ano, Length: 5565, dtype: datetime64[ns]

# %%
df['ano'].dt.year
# Out:
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
#         ...
# 5560    2010
# 5561    2010
# 5562    2010
# 5563    2010
# 5564    2010
# Name: ano, Length: 5565, dtype: int32

# %%
df['ano'].dt.day
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5560    1
# 5561    1
# 5562    1
# 5563    1
# 5564    1
# Name: ano, Length: 5565, dtype: int32

# %%
df['dia'] = df['ano'].dt.day
df
# Out:
#           mun        ano                uf               nome_mun  \
# 0     1100015 2010-01-01          Rondonia  alta floresta d'oeste
# 1     1100023 2010-01-01          Rondonia              ariquemes
# 2     1100031 2010-01-01          Rondonia                 cabixi
# 3     1100049 2010-01-01          Rondonia                 cacoal
# 4     1100056 2010-01-01          Rondonia             cerejeiras
# ...       ...        ...               ...                    ...
# 5560  5222005 2010-01-01             Goias             vianópolis
# 5561  5222054 2010-01-01             Goias         vicentinópolis
# 5562  5222203 2010-01-01             Goias               vila boa
# 5563  5222302 2010-01-01             Goias          vila propício
# 5564  5300108 2010-01-01  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# ...

# %%
df.iloc[[0]]
# Out:
#        mun        ano        uf               nome_mun nome_micro  \
# 0  1100015 2010-01-01  Rondonia  alta floresta d'oeste     cacoal
#
#            nome_meso  espvida  fectot  mort1  mort5  ...  i_freq_prop  idhm  \
# 0  leste rondoniense    70.75    2.24   23.8  25.49  ...          1.0   1.0
#
#    idhm_e  idhm_l  idhm_r  falsa  classificacao_fectot  mapeado  diferenca  \
# 0     1.0     1.0     1.0    1,1                 maior        1         15
#
#    dia
# 0    1
#
# [1 rows x 243 columns]

# %%
df_duplo = pd.concat([df, df.iloc[[0]]])

# %%
df_duplo
# Out:
#           mun        ano                uf               nome_mun  \
# 0     1100015 2010-01-01          Rondonia  alta floresta d'oeste
# 1     1100023 2010-01-01          Rondonia              ariquemes
# 2     1100031 2010-01-01          Rondonia                 cabixi
# 3     1100049 2010-01-01          Rondonia                 cacoal
# 4     1100056 2010-01-01          Rondonia             cerejeiras
# ...       ...        ...               ...                    ...
# 5561  5222054 2010-01-01             Goias         vicentinópolis
# 5562  5222203 2010-01-01             Goias               vila boa
# 5563  5222302 2010-01-01             Goias          vila propício
# 5564  5300108 2010-01-01  Distrito Federal               brasília
# 0     1100015 2010-01-01          Rondonia  alta floresta d'oeste
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# ...

# %%
df_duplo.duplicated(subset=['nome_mun', 'nome_micro', 'nome_meso'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5561    False
# 5562    False
# 5563    False
# 5564    False
# 0        True
# Length: 5566, dtype: bool

# %%
df_duplo = df_duplo.drop_duplicates(subset=['nome_mun', 'nome_micro', 'nome_meso'])
df_duplo
# Out:
#           mun        ano                uf               nome_mun  \
# 0     1100015 2010-01-01          Rondonia  alta floresta d'oeste
# 1     1100023 2010-01-01          Rondonia              ariquemes
# 2     1100031 2010-01-01          Rondonia                 cabixi
# 3     1100049 2010-01-01          Rondonia                 cacoal
# 4     1100056 2010-01-01          Rondonia             cerejeiras
# ...       ...        ...               ...                    ...
# 5560  5222005 2010-01-01             Goias             vianópolis
# 5561  5222054 2010-01-01             Goias         vicentinópolis
# 5562  5222203 2010-01-01             Goias               vila boa
# 5563  5222302 2010-01-01             Goias          vila propício
# 5564  5300108 2010-01-01  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# ...

# %%
df.pivot_table(values="espvida", index="nome_meso", aggfunc="mean")
# Out:
#                                  espvida
# nome_meso
# agreste alagoano               69.404167
# agreste paraibano              70.475152
# agreste pernambucano           69.783803
# agreste potiguar               70.356047
# agreste sergipano              70.658889
# ...                                  ...
# vale do mucuri                 72.481304
# vale do paraíba paulista       75.087949
# vale do rio doce               73.400882
# vale são-franciscano da bahia  70.896667
# zona da mata                   74.417887
#
# [137 rows x 1 columns]

# %%
df.pivot_table(values=['espvida', 'fectot'], index="nome_meso", aggfunc="mean")
# Out:
#                                  espvida    fectot
# nome_meso
# agreste alagoano               69.404167  2.315833
# agreste paraibano              70.475152  2.208636
# agreste pernambucano           69.783803  2.151127
# agreste potiguar               70.356047  2.437209
# agreste sergipano              70.658889  2.135000
# ...                                  ...       ...
# vale do mucuri                 72.481304  2.557391
# vale do paraíba paulista       75.087949  1.970000
# vale do rio doce               73.400882  2.093824
# vale são-franciscano da bahia  70.896667  2.592222
# zona da mata                   74.417887  1.885423
#
# [137 rows x 2 columns]

# %%
df_filt = df[df['espvida'] > 75]

# %%
df_filt.pivot_table(values=['espvida', 'fectot'], index="nome_meso", aggfunc="mean")
# Out:
#                             espvida    fectot
# nome_meso
# araraquara                76.448000  1.805000
# araçatuba                 76.170000  1.806667
# assis                     76.110000  1.888000
# baixadas                  75.545000  2.030000
# bauru                     76.139677  2.030645
# ...                             ...       ...
# vale do itajaí            77.258837  1.888605
# vale do mucuri            76.020000  2.290000
# vale do paraíba paulista  76.466667  1.865000
# vale do rio doce          75.837857  1.967143
# zona da mata              75.939434  1.831321
#
# [79 rows x 2 columns]

# %%
# df_filt.to_csv("saida.csv", index=False)

# %%
df.query('fectot > 2 or espvida > 75')
# Out:
#           mun        ano                uf               nome_mun  \
# 0     1100015 2010-01-01          Rondonia  alta floresta d'oeste
# 2     1100031 2010-01-01          Rondonia                 cabixi
# 4     1100056 2010-01-01          Rondonia             cerejeiras
# 6     1100072 2010-01-01          Rondonia             corumbiara
# 7     1100080 2010-01-01          Rondonia          costa marques
# ...       ...        ...               ...                    ...
# 5560  5222005 2010-01-01             Goias             vianópolis
# 5561  5222054 2010-01-01             Goias         vicentinópolis
# 5562  5222203 2010-01-01             Goias               vila boa
# 5563  5222302 2010-01-01             Goias          vila propício
# 5564  5300108 2010-01-01  Distrito Federal               brasília
#
#                nome_micro          nome_meso  espvida  fectot  mort1  mort5  \
# 0                  cacoal  leste rondoniense    70.75    2.24  23.80  25.49
# ...
